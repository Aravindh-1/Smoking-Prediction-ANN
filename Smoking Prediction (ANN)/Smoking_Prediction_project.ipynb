# %%
import pandas as pd

import tensorflow as tf

from tensorflow import keras

from sklearn.model_selection import train_test_split

import numpy as np

# %%
df = pd.read_csv('/content/Smoker prediction.csv')

# %%
df.head()
# Out:
#    age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  eyesight(right)  \
# 0   35         170          85       97.0             0.9              0.9
# 1   20         175         110      110.0             0.7              0.9
# 2   45         155          65       86.0             0.9              0.9
# 3   45         165          80       94.0             0.8              0.7
# 4   20         165          60       81.0             1.5              0.1
#
#    hearing(left)  hearing(right)  systolic  relaxation  ...  HDL  LDL  \
# 0              1               1       118          78  ...   70  142
# 1              1               1       119          79  ...   71  114
# 2              1               1       110          80  ...   57  112
# 3              1               1       158          88  ...   46   91
# 4              1               1       109          64  ...   47   92
#
#    hemoglobin  Urine protein  serum creatinine   AST   ALT  Gtp  \
# ...

# %%
df = df[:2000]

# %%
df
# Out:
#       age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  eyesight(right)  \
# 0      35         170          85       97.0             0.9              0.9
# 1      20         175         110      110.0             0.7              0.9
# 2      45         155          65       86.0             0.9              0.9
# 3      45         165          80       94.0             0.8              0.7
# 4      20         165          60       81.0             1.5              0.1
# ...   ...         ...         ...        ...             ...              ...
# 1995   30         170          65       86.0             1.2              1.5
# 1996   45         160          80       92.7             1.0              0.7
# 1997   50         155          55       79.0             1.2              1.0
# 1998   40         175          70       79.0             0.7              0.7
# 1999   35         165          60       78.0             1.2              1.2
#
# ...

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of       age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  eyesight(right)  \
# 0      35         170          85       97.0             0.9              0.9
# 1      20         175         110      110.0             0.7              0.9
# 2      45         155          65       86.0             0.9              0.9
# 3      45         165          80       94.0             0.8              0.7
# 4      20         165          60       81.0             1.5              0.1
# ...   ...         ...         ...        ...             ...              ...
# 1995   30         170          65       86.0             1.2              1.5
# 1996   45         160          80       92.7             1.0              0.7
# 1997   50         155          55       79.0             1.2              1.0
# 1998   40         175          70       79.0             0.7              0.7
# 1999   35         165          60       78.0             1.2              1.2
#
# ...

# %%
df.isnull().sum()
# Out:
# age                    0
# height(cm)             0
# weight(kg)             0
# waist(cm)              0
# eyesight(left)         0
# eyesight(right)        0
# hearing(left)          0
# hearing(right)         0
# systolic               0
# relaxation             0
# fasting blood sugar    0
# Cholesterol            0
# triglyceride           0
# HDL                    0
# LDL                    0
# hemoglobin             0
# Urine protein          0
# serum creatinine       0
# AST                    0
# ALT                    0
# Gtp                    0
# dental caries          0
# smoking                0
# dtype: int64

# %%
df.head()
# Out:
#    age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  eyesight(right)  \
# 0   35         170          85       97.0             0.9              0.9
# 1   20         175         110      110.0             0.7              0.9
# 2   45         155          65       86.0             0.9              0.9
# 3   45         165          80       94.0             0.8              0.7
# 4   20         165          60       81.0             1.5              0.1
#
#    hearing(left)  hearing(right)  systolic  relaxation  ...  HDL  LDL  \
# 0              1               1       118          78  ...   70  142
# 1              1               1       119          79  ...   71  114
# 2              1               1       110          80  ...   57  112
# 3              1               1       158          88  ...   46   91
# 4              1               1       109          64  ...   47   92
#
#    hemoglobin  Urine protein  serum creatinine   AST   ALT  Gtp  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)',
#        'eyesight(right)', 'hearing(left)', 'hearing(right)', 'systolic',
#        'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride',
#        'HDL', 'LDL', 'hemoglobin', 'Urine protein', 'serum creatinine', 'AST',
#        'ALT', 'Gtp', 'dental caries', 'smoking'],
#       dtype='object')

# %%
X = df.drop(columns="smoking")

y=df[['smoking']]

# %%
X
# Out:
#       age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  eyesight(right)  \
# 0      35         170          85       97.0             0.9              0.9
# 1      20         175         110      110.0             0.7              0.9
# 2      45         155          65       86.0             0.9              0.9
# 3      45         165          80       94.0             0.8              0.7
# 4      20         165          60       81.0             1.5              0.1
# ...   ...         ...         ...        ...             ...              ...
# 1995   30         170          65       86.0             1.2              1.5
# 1996   45         160          80       92.7             1.0              0.7
# 1997   50         155          55       79.0             1.2              1.0
# 1998   40         175          70       79.0             0.7              0.7
# 1999   35         165          60       78.0             1.2              1.2
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)


model = keras.Sequential([
                          
    keras.layers.Flatten(input_shape=(22,)), #Input Layer
    

    keras.layers.Dense(15, activation=tf.nn.relu), #Hidden Layer 1
	 
    keras.layers.Dense(10, activation=tf.nn.relu),  #Hidden Layer 2
   

    keras.layers.Dense(1, activation=tf.nn.sigmoid), #Output Layer

])


model.compile(optimizer='Adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=20, batch_size=1)

test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/20
# 1600/1600 [==============================] - 4s 2ms/step - loss: 4.3237 - accuracy: 0.6231
# Epoch 2/20
# 1600/1600 [==============================] - 3s 2ms/step - loss: 1.1268 - accuracy: 0.6650
# Epoch 3/20
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.8796 - accuracy: 0.6837
# Epoch 4/20
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.7980 - accuracy: 0.6675
# Epoch 5/20
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.7579 - accuracy: 0.6656
# Epoch 6/20
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6925 - accuracy: 0.6731
# Epoch 7/20
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6570 - accuracy: 0.6888
# Epoch 8/20
# 1600/1600 [==============================] - 4s 2ms/step - loss: 0.6152 - accuracy: 0.6963
# Epoch 9/20
# 1600/1600 [==============================] - 3s 2ms/step - loss: 0.6070 - accuracy: 0.6800
# Epoch 10/20
# ...

# %%
values= np.array([[50,165,80,94.0,1.2,0.9,1,1,128,80,135,169,164,34,102,15.9,1,0.8,28,30,44,0]])

Predict = model.predict(a)


if Predict>0.5:
  print("Smoking Habit is there")
  
else:
  print("No Smoking Habit")
# Out:
# 1/1 [==============================] - 0s 38ms/step
# Smoking Habit is there

# %%
Predict
# Out:
# array([[0.65222436]], dtype=float32)
